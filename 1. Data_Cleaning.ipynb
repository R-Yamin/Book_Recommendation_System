# %% [markdown]
# # Data Wrangling and Cleaning for Goodreads Recommendation System

# %% [markdown]
# ### Import necessary modules and libraries:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Diving into the data:

# %%
# Read CSV file into pandas dataframe
unclean_data = pd.read_csv('Raw_data/goodreadsbooks/books.csv', error_bad_lines=False)
# Out:
# b'Skipping line 4012: expected 10 fields, saw 11\nSkipping line 5688: expected 10 fields, saw 11\nSkipping line 7056: expected 10 fields, saw 11\nSkipping line 10601: expected 10 fields, saw 11\nSkipping line 10668: expected 10 fields, saw 11\n'

# %%
# Explore basic information about unclean data
unclean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13714 entries, 0 to 13713
# Data columns (total 10 columns):
# bookID                13714 non-null int64
# title                 13714 non-null object
# authors               13714 non-null object
# average_rating        13714 non-null float64
# isbn                  13714 non-null object
# isbn13                13714 non-null int64
# language_code         13714 non-null object
# # num_pages           13714 non-null int64
# ratings_count         13714 non-null int64
# text_reviews_count    13714 non-null int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 1.0+ MB

# %%
# Look at head of dataframe
unclean_data.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       3  Harry Potter and the Sorcerer's Stone (Harry P...
# 3       4  Harry Potter and the Chamber of Secrets (Harry...
# 4       5  Harry Potter and the Prisoner of Azkaban (Harr...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling-Mary GrandPré            4.56  0439785960  9780439785969
# 1  J.K. Rowling-Mary GrandPré            4.49  0439358078  9780439358071
# 2  J.K. Rowling-Mary GrandPré            4.47  0439554934  9780439554930
# 3                J.K. Rowling            4.41  0439554896  9780439554893
# 4  J.K. Rowling-Mary GrandPré            4.55  043965548X  9780439655484
#
#   language_code  # num_pages  ratings_count  text_reviews_count
# 0           eng          652        1944099               26249
# 1           eng          870        1996446               27613
# 2           eng          320        5629932               70390
# 3           eng          352           6267                 272
# 4           eng          435        2149872               33964

# %%
# Locate all instances of J.K. Rowling to observe how author is listed in authors column
unclean_data.loc[unclean_data['authors'].str.contains('J.K. Rowling')]
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           3  Harry Potter and the Sorcerer's Stone (Harry P...
# 3           4  Harry Potter and the Chamber of Secrets (Harry...
# 4           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 5           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 7          10       Harry Potter Collection (Harry Potter  #1-6)
# 692      2000                    Conversations with J.K. Rowling
# 693      2002  Harry Potter Schoolbooks Box Set: Two Classic ...
# 695      2005  Harry Potter and the Half-Blood Prince (Harry ...
# 1123     3357  Harry Potter Y La Piedra Filosofal (Harry Pott...
# 1429     4256  Harry Potter and the Prisoner of Azkaban (Harr...
# 2028     5991                                 混血王子的背叛 (哈利波特  #6)
# 2029     6003                                   火盃的考驗 (哈利波特  #4)
# 5294    15872  Harry Potter y el misterio del príncipe (Harry...
# 5295    15875  Harry Potter y la cámara secreta (Harry Potter...
# 5296    15876  Harry Potter y la Orden del Fénix (Harry Potte...
# 5299    15880                 Harrius Potter et Philosophi Lapis
# 5300    15881  Harry Potter and the Chamber of Secrets (Harry...
# 5301    15882                Harrius Potter et Camera Secretorum
# 10519   34258  Harry Potter y la Orden del Fénix (Harry Potte...
# 10520   34260     Гарри Поттер и Орден Феникса (Гарри Поттер #5)
# 10540   34318  Harry Potter and the Sorcerer's Stone (Harry P...
# 12250   41899            Fantastic Beasts and Where to Find Them
# 12253   41907  Harry Potter und die Kammer des Schreckens (Ha...
# 12254   41908  Harry Potter und der Gefangene von Askaban (Ha...
# 12255   41909    Harry Potter ve Sırlar Odası (Harry Potter  #2)
# 12256   41911  Harry Potter und der Gefangene von Askaban (Ha...
# 12257   41912                       Harry Potter ve Felsefe Taşı
# 12660   43504  Harry Potter and the Philosopher's Stone (Harr...
# 12661   43507  Гарри Поттер и философский камень (Harry Potte...
# 12662   43508                  Harry Potter e il Calice di Fuoco
# 12663   43509  Harry Potter and the Goblet of Fire (Harry Pot...
# 13633   47522  Harry Potter und der Stein der Weisen (Harry P...
# 13634   47523        Harry Potter Boxed Set (Harry Potter  #1-4)
# 13637   47532  Harry Potter y el prisionero de Azkaban (Harry...
# 13638   47538  Harry Potter et le Prisonnier d'Azkaban (Harry...
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling-Mary GrandPré            4.56
# 1                             J.K. Rowling-Mary GrandPré            4.49
# 2                             J.K. Rowling-Mary GrandPré            4.47
# 3                                           J.K. Rowling            4.41
# 4                             J.K. Rowling-Mary GrandPré            4.55
# 5                             J.K. Rowling-Mary GrandPré            4.78
# 7                                           J.K. Rowling            4.73
# 692                          Lindsey Fraser-J.K. Rowling            3.99
# 693                                         J.K. Rowling            4.40
# 695                                         J.K. Rowling            4.56
# 1123                                        J.K. Rowling            4.47
# 1429                                        J.K. Rowling            4.55
# 2028           J.K. Rowling-J.K.羅琳-皇冠編譯組-張定綺-彭倩文-趙丕慧-林靜華            4.56
# 2029                             J.K. Rowling-J.K.羅琳-彭倩文            4.55
# 5294                    J.K. Rowling-Gemma Rovira Ortega            4.56
# 5295                                        J.K. Rowling            4.41
# 5296                                        J.K. Rowling            4.49
# 5299                          J.K. Rowling-Peter Needham            4.47
# 5300                          J.K. Rowling-Mary GrandPré            4.41
# 5301                          J.K. Rowling-Peter Needham            4.41
# 10519                                       J.K. Rowling            4.49
# 10520  J.K. Rowling-Дж.К. Ролинг-Владимир Бабков-Викт...            4.49
# 10540                         J.K. Rowling-Mary GrandPré            4.47
# 12250       Newt Scamander-J.K. Rowling-Albus Dumbledore            3.99
# 12253                                       J.K. Rowling            4.41
# 12254                            J.K. Rowling-Rufus Beck            4.55
# 12255                           J.K. Rowling-Sevin Okyay            4.41
# 12256                                       J.K. Rowling            4.55
# 12257                                       J.K. Rowling            4.47
# 12660                                       J.K. Rowling            4.47
# 12661           J.K. Rowling-Дж.К. Ролинг-И.В. Оранского            4.47
# 12662  J.K. Rowling-Serena Daniele-Beatrice Masini-Se...            4.55
# 12663                                       J.K. Rowling            4.55
# 13633                           J.K. Rowling-Klaus Fritz            4.47
# 13634                         J.K. Rowling-Mary GrandPré            4.67
# 13637                                       J.K. Rowling            4.55
# 13638                  J.K. Rowling-Jean-François Ménard            4.55
#
#              isbn         isbn13 language_code  # num_pages  ratings_count  \
# 0      0439785960  9780439785969           eng          652        1944099
# 1      0439358078  9780439358071           eng          870        1996446
# 2      0439554934  9780439554930           eng          320        5629932
# 3      0439554896  9780439554893           eng          352           6267
# 4      043965548X  9780439655484           eng          435        2149872
# 5      0439682584  9780439682589           eng         2690          38872
# 7      0439827604  9780439827607           eng         3342          27410
# 692    0439314550  9780439314558           eng           96           4184
# 693    043932162X  9780439321624           eng          240          11459
# 695    0747584664  9780747584667           eng          768           1173
# 1123   0613359607  9780613359603           spa          254             84
# 1429   074757362X  9780747573623           eng          480           3116
# 2028   9573321742  9789573321743           zho          735             69
# 2029   9573318318  9789573318316           zho          768             82
# 5294   8478889930  9788478889938           spa          602           4572
# 5295   8498380138  9788498380132           spa          288            181
# 5296   8478888845  9788478888849           spa          893           4893
# 5299   1582348251  9781582348254           lat          249            185
# 5300   0439064864  9780439064866           eng          341        2115562
# 5301   159990067X  9781599900674           lat          277             82
# 10519  8478887423  9788478887422           spa          896            953
# 10520  5353014359  9785353014355           rus          828            560
# 10540  0786222727  9780786222728           eng          424            132
# 12250  0439321603  9780439321600           eng          128         240268
# 12253  3551552096  9783551552099           ger          351             25
# 12254  3895849618  9783895849619           ger           13            308
# 12255  3570211029  9783570211021           tur          403            823
# 12256  355155210X  9783551552105           ger          448             28
# 12257  3570211010  9783570211014           tur          353             12
# 12660  158234681X  9781582346816           gla          250             11
# 12661  535300308X  9785353003083           rus          400            425
# 12662  888451049X  9788884510495           ita          627           4983
# 12663  074754624X  9780747546245           eng          636          18097
# 13633  3551354014  9783551354013           ger          334            694
# 13634  0439434866  9780439434867           eng         1820            534
# 13637  8478886559  9788478886555           spa          359           5582
# 13638  2070541304  9782070541300           fre          349            249
#
#        text_reviews_count
# 0                   26249
# 1                   27613
# 2                   70390
# 3                     272
# 4                   33964
# 5                     154
# 7                     820
# 692                    85
# 693                   143
# 695                    72
# 1123                    5
# 1429                  147
# 2028                    0
# 2029                    1
# 5294                  338
# 5295                   15
# 5296                  397
# 5299                   25
# 5300                32694
# 5301                    5
# 10519                  51
# 10520                   5
# 10540                  12
# 12250                5219
# 12253                   1
# 12254                   8
# 12255                  36
# 12256                   2
# 12257                   0
# 12660                   0
# 12661                   7
# 12662                 157
# 12663                 860
# 13633                  44
# 13634                   6
# 13637                 469
# 13638                  11

# %%
# Create clean dataframe to store and eventually save all cleaned data.
clean_data = unclean_data.loc[:, 'bookID':'title']
clean_data.head()
# Out:
#    bookID                                              title
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       3  Harry Potter and the Sorcerer's Stone (Harry P...
# 3       4  Harry Potter and the Chamber of Secrets (Harry...
# 4       5  Harry Potter and the Prisoner of Azkaban (Harr...

# %% [markdown]
# ### 2. Mutliple Authors for Certain Books in the Author Column
# There are multiple authors for certain books, such as Good Omens by Terry Prachet and Neil Gaiman, as well as some illustrators that are included in the author column. Looking at the first few rows for Harry Potter, we see Mary Grandpre, who was an illustrator for the book series, is included here. looking at further rows, there are also translators that are included in this column alongside the original authors of the books. In order to more accurately present the data without removing actual second authors, we will split the authors' column into two seperate columns. The first author will be noted as the primary author (as is the case with many of these books with multiple authors), and the second author as the secondary.

# %%
# Split unclean dataframe authors column at first '-' to ensure primary author has their own column
clean_data[['primary_a','secondary_a']] = unclean_data.authors.str.split('-', 1, expand=True)
clean_data.head()
# Out:
#    bookID                                              title     primary_a  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...  J.K. Rowling
# 1       2  Harry Potter and the Order of the Phoenix (Har...  J.K. Rowling
# 2       3  Harry Potter and the Sorcerer's Stone (Harry P...  J.K. Rowling
# 3       4  Harry Potter and the Chamber of Secrets (Harry...  J.K. Rowling
# 4       5  Harry Potter and the Prisoner of Azkaban (Harr...  J.K. Rowling
#
#      secondary_a
# 0  Mary GrandPré
# 1  Mary GrandPré
# 2  Mary GrandPré
# 3           None
# 4  Mary GrandPré

# %% [markdown]
# ### 3. Join Rest of Data to Clean Dataframe

# %%
# Join 'average_rating' through 'text_reviews_count' columns from unclean data into the clean 
clean_data = clean_data.join(unclean_data.loc[:,'average_rating':'text_reviews_count'])

# %%
clean_data.head()
# Out:
#    bookID                                              title     primary_a  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...  J.K. Rowling
# 1       2  Harry Potter and the Order of the Phoenix (Har...  J.K. Rowling
# 2       3  Harry Potter and the Sorcerer's Stone (Harry P...  J.K. Rowling
# 3       4  Harry Potter and the Chamber of Secrets (Harry...  J.K. Rowling
# 4       5  Harry Potter and the Prisoner of Azkaban (Harr...  J.K. Rowling
#
#      secondary_a  average_rating        isbn         isbn13 language_code  \
# 0  Mary GrandPré            4.56  0439785960  9780439785969           eng
# 1  Mary GrandPré            4.49  0439358078  9780439358071           eng
# 2  Mary GrandPré            4.47  0439554934  9780439554930           eng
# 3           None            4.41  0439554896  9780439554893           eng
# 4  Mary GrandPré            4.55  043965548X  9780439655484           eng
#
#    # num_pages  ratings_count  text_reviews_count
# 0          652        1944099               26249
# 1          870        1996446               27613
# 2          320        5629932               70390
# 3          352           6267                 272
# 4          435        2149872               33964

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13714 entries, 0 to 13713
# Data columns (total 11 columns):
# bookID                13714 non-null int64
# title                 13714 non-null object
# primary_a             13714 non-null object
# secondary_a           5494 non-null object
# average_rating        13714 non-null float64
# isbn                  13714 non-null object
# isbn13                13714 non-null int64
# language_code         13714 non-null object
# # num_pages           13714 non-null int64
# ratings_count         13714 non-null int64
# text_reviews_count    13714 non-null int64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 1.2+ MB

# %% [markdown]
# ### 4. Save Clean DataFrame to Clean Folder

# %%
clean_data.to_csv('Clean_data\clean_books.csv')
